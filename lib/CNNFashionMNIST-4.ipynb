# %% [markdown]
# # 经典卷积模型
#
# 使用经典的卷积 + 最大池化 + FC进行试验
#
# 模型结构如下：
# 1. conv2d(kenel_size=2, stride=2, padding=2)
# 2. ReLU
# 3. MaxPool(kernel_size=2, stride=2)
# 4. conv2d(kenel_size=3, stride=1, padding=1)
# 5. ReLU
# 6. MaxPool(kenel_size=2, stride=2)
# 7. FC(16, 4)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt

# %%
from lib.data_loader import *
from lib.train_test import *

# %%
# 2. 定义模型结构
class CNNModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.conv1 = nn.Conv2d(in_channels=4, out_channels=4, kernel_size=2, stride=2, padding=2)
        self.max_pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(in_channels=4, out_channels=16, kernel_size=3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, stride=1, padding=1)  
        self.relu = nn.ReLU()
        self.fc = nn.Linear(16, 4)
    
    def forward(self, x):
        x = self.conv1(x)           
        # print(x.shape)              # down sacle to 25*4*16*16
        x = self.relu(x)        
        x = self.max_pool(x)        
        # print(x.shape)              # 25*4*8*8
        x = self.conv2(x)           
        # print(x.shape)              # 25*16*4*4
        x = self.relu(x)
        x = self.max_pool(x)       
        # print(x.shape)              # to 25*16*2*2
        x = self.conv3(x)
        # print(x.shape)              # 25*16*2*2
        x = self.relu(x)
        x = self.max_pool(x)
        # print(x.shape)              # 25*16*1*1
        x = self.flatten(x)
        # print(x.shape)              # 25*16
        x = self.fc(x)
        # print(x.shape)              # 25*4
        return x

# %%
# FashionMNIST 数据集加载
transform = transforms.Compose([transforms.ToTensor()])
train_dataset = datasets.FashionMNIST(root="../data", train=True, download=True, transform=transform)
test_dataset = datasets.FashionMNIST(root="../data", train=False, download=True, transform=transform)
train_loader, test_loader = getDataloader(train_dataset, test_dataset, (1, 2, 8, 9), train_size=5000, test_size=1000, batch_size=25, shuffle=True)
# Out:
# Shape of X [N, C, H, W]:+--------------------------------------------------------------- torch.Size([25, 1, 28, 28])
# Shape of y: torch.Size([25]) torch.int64
# train_images's shape is :  torch.Size([25, 1, 28, 28])
# train_labels's shape is :  torch.Size([25])
# Training Samples:
# Testing Samples:

# %%
epochs = 30

# 初始化模型、优化器和损失函数
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CNNModel().to(device)
print(model)
loss_fn = nn.CrossEntropyLoss()
learning_rate = 0.01
optimizer = optim.Adam(model.parameters(), lr = learning_rate)
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_multi_channel(train_loader, model, loss_fn, 25, optimizer, device)
    test_multi_channel(test_loader, model, loss_fn, device)
print("Done!")
# Out:
# CNNModel(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (conv1): Conv2d(4, 4, kernel_size=(2, 2), stride=(2, 2), padding=(2, 2))
#   (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(4, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu): ReLU()
#   (fc): Linear(in_features=16, out_features=4, bias=True)
# )
# Epoch 1
# -------------------------------
# loss: 1.400680  [   25/12000]
# loss: 0.623649  [  650/12000]
# loss: 1.155155  [ 1275/12000]
# loss: 0.207139  [ 1900/12000]
# loss: 0.344233  [ 2525/12000]
# loss: 0.243566  [ 3150/12000]
# loss: 0.203586  [ 3775/12000]
# loss: 0.174369  [ 4400/12000]
# loss: 0.293350  [ 5025/12000]
# loss: 0.203021  [ 5650/12000]
# loss: 0.144911  [ 6275/12000]
# loss: 0.088562  [ 6900/12000]
# loss: 0.174296  [ 7525/12000]
# loss: 0.081938  [ 8150/12000]
# loss: 0.165621  [ 8775/12000]
# loss: 0.020295  [ 9400/12000]
# loss: 0.510234  [10025/12000]
# loss: 0.224121  [10650/12000]
# loss: 0.149120  [11275/12000]
# loss: 0.014645  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.080929
#
# Epoch 2
# -------------------------------
# loss: 0.022191  [   25/12000]
# loss: 0.072173  [  650/12000]
# loss: 0.029143  [ 1275/12000]
# loss: 0.078891  [ 1900/12000]
# loss: 0.010975  [ 2525/12000]
# loss: 0.169755  [ 3150/12000]
# loss: 0.080813  [ 3775/12000]
# loss: 0.078984  [ 4400/12000]
# loss: 0.060180  [ 5025/12000]
# loss: 0.067494  [ 5650/12000]
# loss: 0.116198  [ 6275/12000]
# loss: 0.356168  [ 6900/12000]
# loss: 0.157847  [ 7525/12000]
# loss: 0.167046  [ 8150/12000]
# loss: 0.051198  [ 8775/12000]
# loss: 0.245566  [ 9400/12000]
# loss: 0.026801  [10025/12000]
# loss: 0.121095  [10650/12000]
# loss: 0.072123  [11275/12000]
# loss: 0.073635  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.093381
#
# Epoch 3
# -------------------------------
# loss: 0.032644  [   25/12000]
# loss: 0.028196  [  650/12000]
# loss: 0.124661  [ 1275/12000]
# loss: 0.041724  [ 1900/12000]
# loss: 0.019493  [ 2525/12000]
# loss: 0.567863  [ 3150/12000]
# loss: 0.201599  [ 3775/12000]
# loss: 0.005831  [ 4400/12000]
# loss: 0.198268  [ 5025/12000]
# loss: 0.541098  [ 5650/12000]
# loss: 0.104423  [ 6275/12000]
# loss: 0.011572  [ 6900/12000]
# loss: 0.002817  [ 7525/12000]
# loss: 0.212103  [ 8150/12000]
# loss: 0.010948  [ 8775/12000]
# loss: 0.041216  [ 9400/12000]
# loss: 0.031828  [10025/12000]
# loss: 0.136145  [10650/12000]
# loss: 0.004033  [11275/12000]
# loss: 0.020539  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.077473
#
# Epoch 4
# -------------------------------
# loss: 0.036343  [   25/12000]
# loss: 0.010941  [  650/12000]
# loss: 0.007667  [ 1275/12000]
# loss: 0.028633  [ 1900/12000]
# loss: 0.088365  [ 2525/12000]
# loss: 0.023331  [ 3150/12000]
# loss: 0.039033  [ 3775/12000]
# loss: 0.004792  [ 4400/12000]
# loss: 0.006539  [ 5025/12000]
# loss: 0.007895  [ 5650/12000]
# loss: 0.066170  [ 6275/12000]
# loss: 0.051836  [ 6900/12000]
# loss: 0.112479  [ 7525/12000]
# loss: 0.021066  [ 8150/12000]
# loss: 0.019778  [ 8775/12000]
# loss: 0.128693  [ 9400/12000]
# loss: 0.043684  [10025/12000]
# loss: 0.049884  [10650/12000]
# loss: 0.120943  [11275/12000]
# loss: 0.028298  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.080356
#
# Epoch 5
# -------------------------------
# loss: 0.002916  [   25/12000]
# loss: 0.052544  [  650/12000]
# loss: 0.183027  [ 1275/12000]
# loss: 0.226351  [ 1900/12000]
# loss: 0.061955  [ 2525/12000]
# loss: 0.083344  [ 3150/12000]
# loss: 0.314811  [ 3775/12000]
# loss: 0.065618  [ 4400/12000]
# loss: 0.051501  [ 5025/12000]
# loss: 0.011997  [ 5650/12000]
# loss: 0.011080  [ 6275/12000]
# loss: 0.079056  [ 6900/12000]
# loss: 0.028037  [ 7525/12000]
# loss: 0.047790  [ 8150/12000]
# loss: 0.017378  [ 8775/12000]
# loss: 0.074985  [ 9400/12000]
# loss: 0.144184  [10025/12000]
# loss: 0.088308  [10650/12000]
# loss: 0.039130  [11275/12000]
# loss: 0.090806  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.062324
#
# Epoch 6
# -------------------------------
# loss: 0.124857  [   25/12000]
# loss: 0.008241  [  650/12000]
# loss: 0.000801  [ 1275/12000]
# loss: 0.032850  [ 1900/12000]
# loss: 0.025495  [ 2525/12000]
# loss: 0.080366  [ 3150/12000]
# loss: 0.114366  [ 3775/12000]
# loss: 0.014232  [ 4400/12000]
# loss: 0.017573  [ 5025/12000]
# loss: 0.273528  [ 5650/12000]
# loss: 0.386317  [ 6275/12000]
# loss: 0.027283  [ 6900/12000]
# loss: 0.295935  [ 7525/12000]
# loss: 0.024673  [ 8150/12000]
# loss: 0.240451  [ 8775/12000]
# loss: 0.054714  [ 9400/12000]
# loss: 0.013055  [10025/12000]
# loss: 0.239431  [10650/12000]
# loss: 0.008388  [11275/12000]
# loss: 0.083442  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.077012
#
# Epoch 7
# -------------------------------
# loss: 0.000717  [   25/12000]
# loss: 0.066374  [  650/12000]
# loss: 0.034662  [ 1275/12000]
# loss: 0.172278  [ 1900/12000]
# loss: 0.191958  [ 2525/12000]
# loss: 0.083583  [ 3150/12000]
# loss: 0.018919  [ 3775/12000]
# loss: 0.002049  [ 4400/12000]
# loss: 0.003064  [ 5025/12000]
# loss: 0.227425  [ 5650/12000]
# loss: 0.060810  [ 6275/12000]
# loss: 0.009323  [ 6900/12000]
# loss: 0.019856  [ 7525/12000]
# loss: 0.189512  [ 8150/12000]
# loss: 0.054862  [ 8775/12000]
# loss: 0.211000  [ 9400/12000]
# loss: 0.012647  [10025/12000]
# loss: 0.118658  [10650/12000]
# loss: 0.079015  [11275/12000]
# loss: 0.188553  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.056491
#
# Epoch 8
# -------------------------------
# loss: 0.005689  [   25/12000]
# loss: 0.010493  [  650/12000]
# loss: 0.001416  [ 1275/12000]
# loss: 0.000532  [ 1900/12000]
# loss: 0.027035  [ 2525/12000]
# loss: 0.021255  [ 3150/12000]
# loss: 0.068642  [ 3775/12000]
# loss: 0.002095  [ 4400/12000]
# loss: 0.039504  [ 5025/12000]
# loss: 0.006532  [ 5650/12000]
# loss: 0.046109  [ 6275/12000]
# loss: 0.030039  [ 6900/12000]
# loss: 0.318401  [ 7525/12000]
# loss: 0.035033  [ 8150/12000]
# loss: 0.026426  [ 8775/12000]
# loss: 0.010537  [ 9400/12000]
# loss: 0.084437  [10025/12000]
# loss: 0.049431  [10650/12000]
# loss: 0.035834  [11275/12000]
# loss: 0.005512  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.069422
#
# Epoch 9
# -------------------------------
# loss: 0.047205  [   25/12000]
# loss: 0.171034  [  650/12000]
# loss: 0.089311  [ 1275/12000]
# loss: 0.036926  [ 1900/12000]
# loss: 0.041833  [ 2525/12000]
# loss: 0.132617  [ 3150/12000]
# loss: 0.015053  [ 3775/12000]
# loss: 0.015623  [ 4400/12000]
# loss: 0.024784  [ 5025/12000]
# loss: 0.117919  [ 5650/12000]
# loss: 0.045858  [ 6275/12000]
# loss: 0.058928  [ 6900/12000]
# loss: 0.034007  [ 7525/12000]
# loss: 0.070673  [ 8150/12000]
# loss: 0.078045  [ 8775/12000]
# loss: 0.009486  [ 9400/12000]
# loss: 0.001916  [10025/12000]
# loss: 0.122103  [10650/12000]
# loss: 0.173735  [11275/12000]
# loss: 0.016293  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.094517
#
# Epoch 10
# -------------------------------
# loss: 0.098496  [   25/12000]
# loss: 0.025309  [  650/12000]
# loss: 0.003937  [ 1275/12000]
# loss: 0.080814  [ 1900/12000]
# loss: 0.034267  [ 2525/12000]
# loss: 0.056173  [ 3150/12000]
# loss: 0.027507  [ 3775/12000]
# loss: 0.126818  [ 4400/12000]
# loss: 0.025910  [ 5025/12000]
# loss: 0.039687  [ 5650/12000]
# loss: 0.040624  [ 6275/12000]
# loss: 0.074423  [ 6900/12000]
# loss: 0.133990  [ 7525/12000]
# loss: 0.064846  [ 8150/12000]
# loss: 0.011802  [ 8775/12000]
# loss: 0.015515  [ 9400/12000]
# loss: 0.126218  [10025/12000]
# loss: 0.115759  [10650/12000]
# loss: 0.023017  [11275/12000]
# loss: 0.000974  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.088259
#
# Epoch 11
# -------------------------------
# loss: 0.000302  [   25/12000]
# loss: 0.050434  [  650/12000]
# loss: 0.003132  [ 1275/12000]
# loss: 0.035100  [ 1900/12000]
# loss: 0.031838  [ 2525/12000]
# loss: 0.001182  [ 3150/12000]
# loss: 0.033707  [ 3775/12000]
# loss: 0.018378  [ 4400/12000]
# loss: 0.094804  [ 5025/12000]
# loss: 0.047662  [ 5650/12000]
# loss: 0.000831  [ 6275/12000]
# loss: 0.238880  [ 6900/12000]
# loss: 0.228916  [ 7525/12000]
# loss: 0.091327  [ 8150/12000]
# loss: 0.000287  [ 8775/12000]
# loss: 0.000426  [ 9400/12000]
# loss: 0.059857  [10025/12000]
# loss: 0.093477  [10650/12000]
# loss: 0.111858  [11275/12000]
# loss: 0.005317  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 97.7%, Avg loss: 0.073098
#
# Epoch 12
# -------------------------------
# loss: 0.002403  [   25/12000]
# loss: 0.018542  [  650/12000]
# loss: 0.002776  [ 1275/12000]
# loss: 0.142893  [ 1900/12000]
# loss: 0.020496  [ 2525/12000]
# loss: 0.015510  [ 3150/12000]
# loss: 0.088521  [ 3775/12000]
# loss: 0.006737  [ 4400/12000]
# loss: 0.002765  [ 5025/12000]
# loss: 0.096754  [ 5650/12000]
# loss: 0.014209  [ 6275/12000]
# loss: 0.000322  [ 6900/12000]
# loss: 0.072704  [ 7525/12000]
# loss: 0.223919  [ 8150/12000]
# loss: 0.000886  [ 8775/12000]
# loss: 0.001903  [ 9400/12000]
# loss: 0.139200  [10025/12000]
# loss: 0.000925  [10650/12000]
# loss: 0.000412  [11275/12000]
# loss: 0.006400  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.065324
#
# Epoch 13
# -------------------------------
# loss: 0.001781  [   25/12000]
# loss: 0.044727  [  650/12000]
# loss: 0.004872  [ 1275/12000]
# loss: 0.023858  [ 1900/12000]
# loss: 0.013742  [ 2525/12000]
# loss: 0.066083  [ 3150/12000]
# loss: 0.121211  [ 3775/12000]
# loss: 0.029142  [ 4400/12000]
# loss: 0.010489  [ 5025/12000]
# loss: 0.003166  [ 5650/12000]
# loss: 0.042035  [ 6275/12000]
# loss: 0.051752  [ 6900/12000]
# loss: 0.004796  [ 7525/12000]
# loss: 0.001550  [ 8150/12000]
# loss: 0.071794  [ 8775/12000]
# loss: 0.000717  [ 9400/12000]
# loss: 0.015986  [10025/12000]
# loss: 0.065461  [10650/12000]
# loss: 0.002784  [11275/12000]
# loss: 0.024829  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.074140
#
# Epoch 14
# -------------------------------
# loss: 0.203108  [   25/12000]
# loss: 0.122817  [  650/12000]
# loss: 0.038809  [ 1275/12000]
# loss: 0.004920  [ 1900/12000]
# loss: 0.007216  [ 2525/12000]
# loss: 0.029336  [ 3150/12000]
# loss: 0.208925  [ 3775/12000]
# loss: 0.016895  [ 4400/12000]
# loss: 0.006021  [ 5025/12000]
# loss: 0.106331  [ 5650/12000]
# loss: 0.075818  [ 6275/12000]
# loss: 0.000543  [ 6900/12000]
# loss: 0.393298  [ 7525/12000]
# loss: 0.106325  [ 8150/12000]
# loss: 0.167836  [ 8775/12000]
# loss: 0.005691  [ 9400/12000]
# loss: 0.098614  [10025/12000]
# loss: 0.034421  [10650/12000]
# loss: 0.360449  [11275/12000]
# loss: 0.066451  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.065707
#
# Epoch 15
# -------------------------------
# loss: 0.006034  [   25/12000]
# loss: 0.000753  [  650/12000]
# loss: 0.007159  [ 1275/12000]
# loss: 0.001066  [ 1900/12000]
# loss: 0.000648  [ 2525/12000]
# loss: 0.004909  [ 3150/12000]
# loss: 0.027479  [ 3775/12000]
# loss: 0.002223  [ 4400/12000]
# loss: 0.059567  [ 5025/12000]
# loss: 0.026808  [ 5650/12000]
# loss: 0.017310  [ 6275/12000]
# loss: 0.005961  [ 6900/12000]
# loss: 0.204982  [ 7525/12000]
# loss: 0.000374  [ 8150/12000]
# loss: 0.022175  [ 8775/12000]
# loss: 0.066559  [ 9400/12000]
# loss: 0.005075  [10025/12000]
# loss: 0.021675  [10650/12000]
# loss: 0.081700  [11275/12000]
# loss: 0.017208  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.063038
#
# Epoch 16
# -------------------------------
# loss: 0.017951  [   25/12000]
# loss: 0.064536  [  650/12000]
# loss: 0.031213  [ 1275/12000]
# loss: 0.007715  [ 1900/12000]
# loss: 0.001082  [ 2525/12000]
# loss: 0.079002  [ 3150/12000]
# loss: 0.020668  [ 3775/12000]
# loss: 0.017693  [ 4400/12000]
# loss: 0.001540  [ 5025/12000]
# loss: 0.039681  [ 5650/12000]
# loss: 0.035457  [ 6275/12000]
# loss: 0.114055  [ 6900/12000]
# loss: 0.088884  [ 7525/12000]
# loss: 0.208610  [ 8150/12000]
# loss: 0.000906  [ 8775/12000]
# loss: 0.128007  [ 9400/12000]
# loss: 0.158233  [10025/12000]
# loss: 0.005334  [10650/12000]
# loss: 0.022509  [11275/12000]
# loss: 0.011090  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.067827
#
# Epoch 17
# -------------------------------
# loss: 0.047640  [   25/12000]
# loss: 0.060781  [  650/12000]
# loss: 0.053762  [ 1275/12000]
# loss: 0.120895  [ 1900/12000]
# loss: 0.116864  [ 2525/12000]
# loss: 0.017335  [ 3150/12000]
# loss: 0.138958  [ 3775/12000]
# loss: 0.087337  [ 4400/12000]
# loss: 0.061575  [ 5025/12000]
# loss: 0.090310  [ 5650/12000]
# loss: 0.012609  [ 6275/12000]
# loss: 0.153273  [ 6900/12000]
# loss: 0.003693  [ 7525/12000]
# loss: 0.062837  [ 8150/12000]
# loss: 0.003324  [ 8775/12000]
# loss: 0.033831  [ 9400/12000]
# loss: 0.012670  [10025/12000]
# loss: 0.000884  [10650/12000]
# loss: 0.172483  [11275/12000]
# loss: 0.014761  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 98.1%, Avg loss: 0.065369
#
# Epoch 18
# -------------------------------
# loss: 0.052304  [   25/12000]
# loss: 0.002506  [  650/12000]
# loss: 0.015591  [ 1275/12000]
# loss: 0.084292  [ 1900/12000]
# loss: 0.003409  [ 2525/12000]
# loss: 0.009266  [ 3150/12000]
# loss: 0.009593  [ 3775/12000]
# loss: 0.030614  [ 4400/12000]
# loss: 0.003257  [ 5025/12000]
# loss: 0.005018  [ 5650/12000]
# loss: 0.336873  [ 6275/12000]
# loss: 0.012254  [ 6900/12000]
# loss: 0.005851  [ 7525/12000]
# loss: 0.005772  [ 8150/12000]
# loss: 0.089700  [ 8775/12000]
# loss: 0.223854  [ 9400/12000]
# loss: 0.013278  [10025/12000]
# loss: 0.018010  [10650/12000]
# loss: 0.003411  [11275/12000]
# loss: 0.002689  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.079936
#
# Epoch 19
# -------------------------------
# loss: 0.072295  [   25/12000]
# loss: 0.003067  [  650/12000]
# loss: 0.020514  [ 1275/12000]
# loss: 0.005768  [ 1900/12000]
# loss: 0.000441  [ 2525/12000]
# loss: 0.287336  [ 3150/12000]
# loss: 0.009845  [ 3775/12000]
# loss: 0.000030  [ 4400/12000]
# loss: 0.001104  [ 5025/12000]
# loss: 0.001152  [ 5650/12000]
# loss: 0.006152  [ 6275/12000]
# loss: 0.007666  [ 6900/12000]
# loss: 0.029005  [ 7525/12000]
# loss: 0.056170  [ 8150/12000]
# loss: 0.162872  [ 8775/12000]
# loss: 0.003050  [ 9400/12000]
# loss: 0.072397  [10025/12000]
# loss: 0.031453  [10650/12000]
# loss: 0.006812  [11275/12000]
# loss: 0.029270  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.077887
#
# Epoch 20
# -------------------------------
# loss: 0.002042  [   25/12000]
# loss: 0.082409  [  650/12000]
# loss: 0.021186  [ 1275/12000]
# loss: 0.163063  [ 1900/12000]
# loss: 0.003398  [ 2525/12000]
# loss: 0.009102  [ 3150/12000]
# loss: 0.033190  [ 3775/12000]
# loss: 0.002282  [ 4400/12000]
# loss: 0.182740  [ 5025/12000]
# loss: 0.413793  [ 5650/12000]
# loss: 0.007695  [ 6275/12000]
# loss: 0.009419  [ 6900/12000]
# loss: 0.006069  [ 7525/12000]
# loss: 0.018402  [ 8150/12000]
# loss: 0.014041  [ 8775/12000]
# loss: 0.001432  [ 9400/12000]
# loss: 0.000106  [10025/12000]
# loss: 0.034484  [10650/12000]
# loss: 0.003710  [11275/12000]
# loss: 0.018218  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.071149
#
# Epoch 21
# -------------------------------
# loss: 0.004258  [   25/12000]
# loss: 0.002503  [  650/12000]
# loss: 0.068055  [ 1275/12000]
# loss: 0.078175  [ 1900/12000]
# loss: 0.000142  [ 2525/12000]
# loss: 0.001533  [ 3150/12000]
# loss: 0.094432  [ 3775/12000]
# loss: 0.001582  [ 4400/12000]
# loss: 0.057333  [ 5025/12000]
# loss: 0.030527  [ 5650/12000]
# loss: 0.011384  [ 6275/12000]
# loss: 0.399122  [ 6900/12000]
# loss: 0.045226  [ 7525/12000]
# loss: 0.005491  [ 8150/12000]
# loss: 0.018807  [ 8775/12000]
# loss: 0.137245  [ 9400/12000]
# loss: 0.024605  [10025/12000]
# loss: 0.146409  [10650/12000]
# loss: 0.000602  [11275/12000]
# loss: 0.141627  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.104855
#
# Epoch 22
# -------------------------------
# loss: 0.117484  [   25/12000]
# loss: 0.162334  [  650/12000]
# loss: 0.062495  [ 1275/12000]
# loss: 0.074063  [ 1900/12000]
# loss: 0.004399  [ 2525/12000]
# loss: 0.017634  [ 3150/12000]
# loss: 0.085991  [ 3775/12000]
# loss: 0.209855  [ 4400/12000]
# loss: 0.062457  [ 5025/12000]
# loss: 0.001100  [ 5650/12000]
# loss: 0.000408  [ 6275/12000]
# loss: 0.098492  [ 6900/12000]
# loss: 0.006294  [ 7525/12000]
# loss: 0.112843  [ 8150/12000]
# loss: 0.257243  [ 8775/12000]
# loss: 0.004119  [ 9400/12000]
# loss: 0.051526  [10025/12000]
# loss: 0.027579  [10650/12000]
# loss: 0.207644  [11275/12000]
# loss: 0.008914  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.064907
#
# Epoch 23
# -------------------------------
# loss: 0.004105  [   25/12000]
# loss: 0.267391  [  650/12000]
# loss: 0.026679  [ 1275/12000]
# loss: 0.013024  [ 1900/12000]
# loss: 0.000372  [ 2525/12000]
# loss: 0.005805  [ 3150/12000]
# loss: 0.043854  [ 3775/12000]
# loss: 0.000363  [ 4400/12000]
# loss: 0.034152  [ 5025/12000]
# loss: 0.004490  [ 5650/12000]
# loss: 0.122632  [ 6275/12000]
# loss: 0.006993  [ 6900/12000]
# loss: 0.207061  [ 7525/12000]
# loss: 0.045167  [ 8150/12000]
# loss: 0.221891  [ 8775/12000]
# loss: 0.010021  [ 9400/12000]
# loss: 0.069586  [10025/12000]
# loss: 0.001896  [10650/12000]
# loss: 0.001478  [11275/12000]
# loss: 0.099102  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.089518
#
# Epoch 24
# -------------------------------
# loss: 0.013756  [   25/12000]
# loss: 0.412756  [  650/12000]
# loss: 0.026240  [ 1275/12000]
# loss: 0.035772  [ 1900/12000]
# loss: 0.001248  [ 2525/12000]
# loss: 0.119654  [ 3150/12000]
# loss: 0.026097  [ 3775/12000]
# loss: 0.048794  [ 4400/12000]
# loss: 0.043067  [ 5025/12000]
# loss: 0.149229  [ 5650/12000]
# loss: 0.269883  [ 6275/12000]
# loss: 0.003376  [ 6900/12000]
# loss: 0.008522  [ 7525/12000]
# loss: 0.002274  [ 8150/12000]
# loss: 0.001868  [ 8775/12000]
# loss: 0.004480  [ 9400/12000]
# loss: 0.004842  [10025/12000]
# loss: 0.011066  [10650/12000]
# loss: 0.005683  [11275/12000]
# loss: 0.011801  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.081723
#
# Epoch 25
# -------------------------------
# loss: 0.120852  [   25/12000]
# loss: 0.008357  [  650/12000]
# loss: 0.000693  [ 1275/12000]
# loss: 0.007066  [ 1900/12000]
# loss: 0.105803  [ 2525/12000]
# loss: 0.065933  [ 3150/12000]
# loss: 0.111676  [ 3775/12000]
# loss: 0.005895  [ 4400/12000]
# loss: 0.000268  [ 5025/12000]
# loss: 0.002626  [ 5650/12000]
# loss: 0.176783  [ 6275/12000]
# loss: 0.012203  [ 6900/12000]
# loss: 0.041657  [ 7525/12000]
# loss: 0.000886  [ 8150/12000]
# loss: 0.003116  [ 8775/12000]
# loss: 0.001749  [ 9400/12000]
# loss: 0.023219  [10025/12000]
# loss: 0.032125  [10650/12000]
# loss: 0.183536  [11275/12000]
# loss: 0.055702  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 97.7%, Avg loss: 0.086473
#
# Epoch 26
# -------------------------------
# loss: 0.027465  [   25/12000]
# loss: 0.001928  [  650/12000]
# loss: 0.100361  [ 1275/12000]
# loss: 0.166931  [ 1900/12000]
# loss: 0.000414  [ 2525/12000]
# loss: 0.000628  [ 3150/12000]
# loss: 0.011597  [ 3775/12000]
# loss: 0.000387  [ 4400/12000]
# loss: 0.105795  [ 5025/12000]
# loss: 0.258367  [ 5650/12000]
# loss: 0.132315  [ 6275/12000]
# loss: 0.007160  [ 6900/12000]
# loss: 0.002077  [ 7525/12000]
# loss: 0.004952  [ 8150/12000]
# loss: 0.092835  [ 8775/12000]
# loss: 0.002326  [ 9400/12000]
# loss: 0.003058  [10025/12000]
# loss: 0.014109  [10650/12000]
# loss: 0.036904  [11275/12000]
# loss: 0.003559  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.104201
#
# Epoch 27
# -------------------------------
# loss: 0.113337  [   25/12000]
# loss: 0.020902  [  650/12000]
# loss: 0.012324  [ 1275/12000]
# loss: 0.236254  [ 1900/12000]
# loss: 0.006652  [ 2525/12000]
# loss: 0.003151  [ 3150/12000]
# loss: 0.013308  [ 3775/12000]
# loss: 0.001463  [ 4400/12000]
# loss: 0.014471  [ 5025/12000]
# loss: 0.195873  [ 5650/12000]
# loss: 0.001307  [ 6275/12000]
# loss: 0.066326  [ 6900/12000]
# loss: 0.012261  [ 7525/12000]
# loss: 0.004295  [ 8150/12000]
# loss: 0.376927  [ 8775/12000]
# loss: 0.025472  [ 9400/12000]
# loss: 0.355332  [10025/12000]
# loss: 0.038619  [10650/12000]
# loss: 0.005814  [11275/12000]
# loss: 0.007579  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.070316
#
# Epoch 28
# -------------------------------
# loss: 0.104478  [   25/12000]
# loss: 0.002218  [  650/12000]
# loss: 0.000728  [ 1275/12000]
# loss: 0.003799  [ 1900/12000]
# loss: 0.008216  [ 2525/12000]
# loss: 0.004384  [ 3150/12000]
# loss: 0.074332  [ 3775/12000]
# loss: 0.004434  [ 4400/12000]
# loss: 0.056173  [ 5025/12000]
# loss: 0.008718  [ 5650/12000]
# loss: 0.080410  [ 6275/12000]
# loss: 0.010760  [ 6900/12000]
# loss: 0.079269  [ 7525/12000]
# loss: 0.000113  [ 8150/12000]
# loss: 0.236212  [ 8775/12000]
# loss: 0.012001  [ 9400/12000]
# loss: 0.000218  [10025/12000]
# loss: 0.000919  [10650/12000]
# loss: 0.023570  [11275/12000]
# loss: 0.003946  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.121640
#
# Epoch 29
# -------------------------------
# loss: 0.001804  [   25/12000]
# loss: 0.106176  [  650/12000]
# loss: 0.004075  [ 1275/12000]
# loss: 0.041984  [ 1900/12000]
# loss: 0.046896  [ 2525/12000]
# loss: 0.021092  [ 3150/12000]
# loss: 0.038516  [ 3775/12000]
# loss: 0.000596  [ 4400/12000]
# loss: 0.001153  [ 5025/12000]
# loss: 0.001221  [ 5650/12000]
# loss: 0.030471  [ 6275/12000]
# loss: 0.017867  [ 6900/12000]
# loss: 0.038061  [ 7525/12000]
# loss: 0.016241  [ 8150/12000]
# loss: 0.286920  [ 8775/12000]
# loss: 0.170946  [ 9400/12000]
# loss: 0.004965  [10025/12000]
# loss: 0.006468  [10650/12000]
# loss: 0.005734  [11275/12000]
# loss: 0.021886  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.081805
#
# Epoch 30
# -------------------------------
# loss: 0.018814  [   25/12000]
# loss: 0.047137  [  650/12000]
# loss: 0.000088  [ 1275/12000]
# loss: 0.000027  [ 1900/12000]
# loss: 0.005873  [ 2525/12000]
# loss: 0.002079  [ 3150/12000]
# loss: 0.028137  [ 3775/12000]
# loss: 0.031733  [ 4400/12000]
# loss: 0.044909  [ 5025/12000]
# loss: 0.009607  [ 5650/12000]
# loss: 0.000452  [ 6275/12000]
# loss: 0.003679  [ 6900/12000]
# loss: 0.000280  [ 7525/12000]
# loss: 0.001202  [ 8150/12000]
# loss: 0.058522  [ 8775/12000]
# loss: 0.061709  [ 9400/12000]
# loss: 0.000452  [10025/12000]
# loss: 0.001802  [10650/12000]
# loss: 0.009542  [11275/12000]
# loss: 0.029060  [11900/12000]
# size: 2400
# num_batches: 96
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.090475
#
# Done!
